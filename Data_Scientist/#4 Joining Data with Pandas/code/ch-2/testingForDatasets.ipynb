# %%
import pandas as pd
import numpy as np

# %%
# data = [
#     {"id": 17857, "name": "Shaun Toub", "character": "Yinsen"},
#     {"id": 12052, "name": "Gwyneth Paltrow", "character": 'Virginia "Pepper" Potts'},
#     {"id": 1229, "name": "Jeff Bridges", "character": 'Obadiah Stane / Iron Monger'},
#     {"id": 18288, "name": "Terrence Howard", "character": "War Machine"},
#     {"id": 57451, "name": "Leslie Bibb", "character": "Christine Everhart"},
#     {"id": 57452, "name": "Faran Tahir", "character": "Raza"},
#     {"id": 3223, "name": "Robert Downey Jr.", "character": 'Tony Stark / Iron Man'},
#     {"id": 9048, "name": "Clark Gregg", "character": "Agent Phil Coulson"},
#     {"id": 173810, "name": "Sayed Badreya", "character": "Abu Bakaar"},
#     {"id": 6162, "name": "Paul Bettany", "character": 'J.A.R.V.I.S. (voice)'},
#     {"id": 15277, "name": "Jon Favreau", "character": "Happy Hogan"},
#     {"id": 12708, "name": "Peter Billingsley", "character": "William Ginter Riva"},
#     {"id": 40275, "name": "Tim Guinee", "character": "Major Allen"},
#     {"id": 2231, "name": "Samuel L. Jackson", "character": "Director Nick Fury"},
#     {"id": 17200, "name": "Bill Smitrovich", "character": "General Gabriel"},
#     {"id": 163671, "name": "Will Lyman", "character": 'Award Ceremony Narrator (voice)'},
#     {"id": 78299, "name": "Tom Morello", "character": "Guard"},
#     {"id": 54809, "name": "Marco Khan", "character": "Guard"},
#     {"id": 944830, "name": "Daston Kalili", "character": "Guard"},
#     {"id": 1209417, "name": "Ido Ezra", "character": "Guard"},
#     {"id": 95698, "name": "Kevin Foster", "character": "Jimmy"},
#     {"id": 1209418, "name": "Garret Noël", "character": "Pratt"},
#     {"id": 62037, "name": "Eileen Weisinger", "character": "Ramirez"},
#     {"id": 183439, "name": "Ahmed Ahmed", "character": "Ahmed"},
#     {"id": 109669, "name": "Fahim Fazli", "character": "Omar"},
#     {"id": 104669, "name": "Gerard Sanders", "character": "Howard Stark"},
#     {"id": 1209419, "name": "Tim Rigby", "character": "Viper 1"},
#     {"id": 195442, "name": "Russell Richardson", "character": "Viper 2"},
#     {"id": 142213, "name": "Nazanin Boniadi", "character": "Amira Ahmed"},
#     {"id": 1209702, "name": "Thomas Craig Plumer", "character": "Colonel Craig"},
#     {"id": 1209703, "name": "Robert Berkman", "character": "Dealer at Craps Table"},
#     {"id": 183037, "name": "Stacy Stas", "character": "Woman at Craps Table"},
#     {"id": 1209704, "name": "Lauren Scyphers", "character": "Woman at Craps Table"},
#     {"id": 214951, "name": "Frank Nyi", "character": "Engineer"},
#     {"id": 205362, "name": "Marvin Jordan", "character": "Air Force Officer"},
#     {"id": 203468, "name": "Jim Cramer", "character": "Jim Cramer"},
#     {"id": 939869, "name": "Donna Evans", "character": "Woman In SUV"},
#     {"id": 1209705, "name": "Reid Harper", "character": "Kid in SUV"},
#     {"id": 1209706, "name": "Summer Kylie Remington", "character": "Kid in SUV"},
#     {"id": 1209707, "name": "Ava Rose Williams", "character": "Kid in SUV"},
#     {"id": 1209708, "name": "Vladimir Kubr", "character": "Kid in SUV"},
#     {"id": 1209709, "name": "Callie Croughwell", "character": "Kid in SUV"},
#     {"id": 1209710, "name": "Javan Tahir", "character": "Gulmira Kid"},
#     {"id": 206423, "name": "Sahar Bibiyan", "character": "Gulmira Mom"},
#     {"id": 133121, "name": "Patrick O'Connell", "character": "Reporter"},
#     {"id": 181895, "name": "Adam Harrington", "character": "Reporter"},
#     {"id": 62843, "name": "Meera Simhan", "character": "Reporter"},
#     {"id": 204606, "name": "Ben Newmark", "character": "Reporter"},
#     {"id": 210842, "name": "Ricki Lander", "character": "Flight Attendant"},
#     {"id": 205720, "name": "Jeannine Kaspar", "character": "Flight Attendant"},
#     {"id": 1005698, "name": "Sarah Cahill", "character": "Flight Attendant"},
#     {"id": 7624, "name": "Stan Lee", "character": "Stan Lee"},
#     {"id": 1209711, "name": "Justin Rex", "character": "Air Force Lieutenant"},
#     {"id": 90721, "name": "Zorianna Kit", "character": "Zorianna Kit"},
#     {"id": 169681, "name": "Lana Kinnear", "character": "Stan's Girl"},
#     {"id": 1209712, "name": "Nicole Lindeblad", "character": "Stan's Girl"},
#     {"id": 1209713, "name": "Masha Lund", "character": "Stan's Girl"},
#     {"id": 169642, "name": "Gabrielle Tuite", "character": "Stan's Girl"},
#     {"id": 27031, "name": "Tim Griffin", "character": "CAOC Analyst"},
#     {"id": 34544, "name": "Joshua Harto", "character": "CAOC Analyst"},
#     {"id": 150669, "name": "Micah A. Hauptman", "character": "CAOC Analyst"},
#     {"id": 1209714, "name": "James Bethea", "character": "CAOC Analyst"},
#     {"id": 1209715, "name": "Jeffrey Ashkin", "character": "Photographer (uncredited)"},
#     {"id": 1004624, "name": "Russell Bobbitt", "character": "Georgio (uncredited)"},
#     {"id": 984619, "name": "Vianessa Castaños", "character": "Fireman's Wife (uncredited)"},
#     {"id": 1209716, "name": "Mike Cochrane", "character": "Gulmira Villager (uncredited)"},
#     {"id": 1209717, "name": "Crystal Marie Denha", "character": "Dubai Beauty (uncredited)"},
#     {"id": 970218, "name": "Mellany Gandara", "character": "Dubai Girl (uncredited)"},
#     {"id": 1209718, "name": "Halla", "character": "House wife at Award Ceremony (uncredited)"},
#     {"id": 1202546, "name": "Rodrick Hersh", "character": "Insurgent (uncredited)"},
#     {"id": 1209719, "name": "Kristin J. Hooper", "character": "Reporter (uncredited)"},
#     {"id": 1209720, "name": "Chris Jalandoni", "character": "Dubai Waiter (uncredited)"},
#     {"id": 1209721, "name": "Steve Janousek", "character": "Party Guest (uncredited)"},
#     {"id": 1209722, "name": "Laura Liguori", "character": "Dancer in Ballroom (uncredited)"},
#     {"id": 1089759, "name": "Flavia Manes Rossi", "character": "Reporter (uncredited)"},
#     {"id": 1096679, "name": "Anthony Martins", "character": "Village Dad (uncredited)"},
#     {"id": 1209723, "name": "Robert McMurrer", "character": "Reporter (uncredited)"},
#     {"id": 1209724, "name": "James M. Myers", "character": "Airforce Officer (uncredited)"},
#     {"id": 78434, "name": "America Olivo", "character": "Dubai Beauty #1 (uncredited)"},
#     {"id": 1209725, "name": "Sylvette Ortiz", "character": "Staff Sergeant (uncredited)"},
#     {"id": 1209726, "name": "Brett Padelford", "character": "Journalist (uncredited)"},
#     {"id": 1209727, "name": "Ajani Perkins", "character": "Voice (uncredited)"},
#     {"id": 1209728, "name": "Chris Reid", "character": "Reporter (uncredited)"},
#     {"id": 1209729, "name": "Toi Rose", "character": "News Cameraman (uncredited)"},
#     {"id": 1209730, "name": "George F. Watson", "character": "Rooftop Fireman (uncredited)"},
#     {"id": 1209731, "name": "David Zyler", "character": "Whiplash One (voice) (uncredited)"},
#     {"id": 1429470, "name": "Nick W. Nicholson", "character": "Reporter (uncredited)"}
# ]

# data = pd.DataFrame(data)
# print(data)
# Out:
#          id               name                          character
# 0     17857         Shaun Toub                             Yinsen
# 1     12052    Gwyneth Paltrow            Virginia "Pepper" Potts
# 2      1229       Jeff Bridges        Obadiah Stane / Iron Monger
# 3     18288    Terrence Howard                        War Machine
# 4     57451        Leslie Bibb                 Christine Everhart
# ..      ...                ...                                ...
# 82  1209728         Chris Reid              Reporter (uncredited)
# 83  1209729           Toi Rose        News Cameraman (uncredited)
# 84  1209730   George F. Watson       Rooftop Fireman (uncredited)
# 85  1209731        David Zyler  Whiplash One (voice) (uncredited)
# 86  1429470  Nick W. Nicholson              Reporter (uncredited)
#
# [87 rows x 3 columns]

# %%
# data.to_csv('iron_1_actors.csv', index=False)

# %%
# # Data
# data = [
#     {"character": "Ivan Vanko / Whiplash", "id": 2295, "name": "Mickey Rourke"},
#     {"character": "Natalie Rushman / Natasha Romanoff / Black Widow", "id": 1245, "name": "Scarlett Johansson"},
#     {"character": "Justin Hammer", "id": 6807, "name": "Sam Rockwell"},
#     {"character": "Director Nick Fury", "id": 2231, "name": "Samuel L. Jackson"},
#     {"character": "Virginia 'Pepper' Potts", "id": 12052, "name": "Gwyneth Paltrow"},
#     {"character": "Lt. Col. James 'Rhodey' Rhodes / War Machine", "id": 1896, "name": "Don Cheadle"},
#     {"character": "Happy Hogan", "id": 15277, "name": "Jon Favreau"},
#     {"character": "Christine Everhart", "id": 57451, "name": "Leslie Bibb"},
#     {"character": "Chess Roberts", "id": 81364, "name": "Olivia Munn"},
#     {"character": "U.S. Marshal", "id": 51072, "name": "Kate Mara"},
#     {"character": "Rebecca", "id": 113676, "name": "Helena Mattsson"},
#     {"character": "Tony Stark / Iron Man", "id": 3223, "name": "Robert Downey Jr."},
#     {"character": "Senator Stern", "id": 52865, "name": "Garry Shandling"},
#     {"character": "Howard Stark", "id": 21134, "name": "John Slattery"},
#     {"character": "Agent Phil Coulson", "id": 9048, "name": "Clark Gregg"},
#     {"character": "J.A.R.V.I.S. (voice)", "id": 6162, "name": "Paul Bettany"},
#     {"character": "Herself", "id": 73641, "name": "Christiane Amanpour"},
#     {"character": "Detective Lemieux", "id": 14741, "name": "Philippe Bergeron"},
#     {"character": "Security Force #1", "id": 1209714, "name": "James Bethea"},
#     {"character": "Security Force #2", "id": 216601, "name": "Michael Bruno"},
#     {"character": "Expo Fan", "id": 1265248, "name": "Kate Clark"},
#     {"character": "Russian Newscaster", "id": 1265249, "name": "Luminita Docan"},
#     {"character": "French Photographer", "id": 1177850, "name": "François Duhamel"},
#     {"character": "Himself", "id": 586090, "name": "Larry Ellison"},
#     {"character": "Himself", "id": 1228219, "name": "Adam Goldstein"},
#     {"character": "Major Allen", "id": 40275, "name": "Tim Guinee"},
#     {"character": "General Meade", "id": 1230885, "name": "Eric L. Haney"},
#     {"character": "10 Rings Gangster", "id": 1265250, "name": "Ali Khan"},
#     {"character": "Anton Vanko", "id": 1079976, "name": "Evgeniy Lazarev"},
#     {"character": "Himself", "id": 7624, "name": "Stan Lee"},
#     {"character": "AV Operator", "id": 1265251, "name": "Isaiah Guyman Martin IV"},
#     {"character": "Expo Cop", "id": 118755, "name": "Keith Middlebrook"},
#     {"character": "Rebeka", "id": 210292, "name": "Anya Monzikova"},
#     {"character": "Bambi Arbogast", "id": 1265252, "name": "Margy Moore"},
#     {"character": "Himself", "id": 57563, "name": "Elon Musk"},
#     {"character": "Himself", "id": 95777, "name": "Bill O'Reilly"},
#     {"character": "Strawberry Vendor", "id": 81957, "name": "Alejandro Patino"},
#     {"character": "Young Tony Stark", "id": 1265795, "name": "Davin Ransom"},
#     {"character": "Guard", "id": 997632, "name": "Karim Saleh"},
#     {"character": "Hammer Expo Tech", "id": 1265796, "name": "Brian Schaeffer"},
#     {"character": "French Waiter", "id": 201883, "name": "Phillipe Simon"},
#     {"character": "Jack", "id": 1265797, "name": "Jack White"},
#     {"character": "Ironette Dancer", "id": 1265798, "name": "Melanie Brown"},
#     {"character": "Ironette Dancer", "id": 1003061, "name": "Krystal Ellsworth"},
#     {"character": "Ironette Dancer", "id": 1265799, "name": "Victoria Gracie"},
#     {"character": "Ironette Dancer", "id": 1202543, "name": "Gina Cantrell"},
#     {"character": "Ironette Dancer", "id": 1265800, "name": "Renee Herlocker"},
#     {"character": "Ironette Dancer", "id": 1265801, "name": "Jill Ann Pineda-Arnold"},
#     {"character": "Ironette Dancer", "id": 571240, "name": "Sandy Colton"},
#     {"character": "Ironette Dancer", "id": 1265802, "name": "Annika Ihnat"},
#     {"character": "Ironette Dancer", "id": 108725, "name": "Jenny Robinson"},
#     {"character": "Ironette Dancer", "id": 1265803, "name": "Lindsay Dennis"},
#     {"character": "Ironette Dancer", "id": 995348, "name": "Jennifer D. Johnson"},
#     {"character": "Ironette Dancer", "id": 1265804, "name": "Lindsay Rosenberg"},
#     {"character": "Ironette Dancer", "id": 1265805, "name": "Hannah Douglass"},
#     {"character": "Ironette Dancer", "id": 1265806, "name": "Brooke Long"},
#     {"character": "Ironette Dancer", "id": 83274, "name": "Rachele Brooke Smith"},
#     {"character": "Ironette Dancer", "id": 168925, "name": "Nadine Ellis"},
#     {"character": "Ironette Dancer", "id": 1265807, "name": "Kylette Zamora"},
#     {"character": "News Cameraman (uncredited)", "id": 98999, "name": "Ted Alderman"},
#     {"character": "Birthday Party Guest / Expo Guest (uncredited)", "id": 1265808, "name": "Donessa Alexander"},
#     {"character": "Expo Greeter (uncredited)", "id": 1265809, "name": "Martin Andris"},
#     {"character": "Expo Patron (uncredited)", "id": 1265810, "name": "Cassity Atkins"},
#     {"character": "Monaco Grand Prix Restaurant Guest (uncredited)", "id": 1265811, "name": "Gregory Baldi"},
#     {"character": "Bartender (uncredited)", "id": 1265812, "name": "Elya Beer"},
#     {"character": "Model (uncredited)", "id": 1265813, "name": "Ayelet Ben-Shahar"},
#     {"character": "Little Girl at EXPO Gala (uncredited)", "id": 1265814, "name": "Jordan Bobbitt"},
#     {"character": "Dignitary / Expo Attendee (uncredited)", "id": 1265815, "name": "Chris Borden"},
#     {"character": "Air Force Major (uncredited)", "id": 1078574, "name": "Pete Brown"},
#     {"character": "Tony Stark Racing Fan (uncredited)", "id": 1265816, "name": "Basilina Butler"},
#     {"character": "Captain Anders (uncredited)", "id": 1236642, "name": "John Ceallach"},
#     {"character": "Beautiful Girl (uncredited)", "id": 1231548, "name": "Katie Cleary"},
#     {"character": "Expo Guest (uncredited)", "id": 1265817, "name": "Ajarae Coleman"},
#     {"character": "Monte Carlo Race Fan (uncredited)", "id": 1265818, "name": "Rick L. Dean"},
#     {"character": "French Prison Guard #2 (uncredited)", "id": 1265819, "name": "Timothy 'TJ' James Driscoll"},
#     {"character": "Watermelon Girl (uncredited)", "id": 1225936, "name": "Jasmine Dustin"},
#     {"character": "Justin Hammer Expo Attendee (uncredited)", "id": 97447, "name": "Mark Casimir Dyniewicz"},
#     {"character": "Stark Expo Attendee (uncredited)", "id": 1265820, "name": "Sam Felman"},
#     {"character": "I Love You girl (uncredited)", "id": 1265821, "name": "Caitlin Gallo"},
#     {"character": "Pepper's Party Guest (uncredited)", "id": 1265822, "name": "Shakira Vanise Gamble"},
#     {"character": "French Prison Guard #1 (uncredited)", "id": 1265823, "name": "Paul Grace"},
#     {"character": "Expo Fan (uncredited)", "id": 1265824, "name": "James Granville"},
#     {"character": "Expo Attendee (uncredited)", "id": 1265825, "name": "Kathryn Henzler"},
#     {"character": "Expo Attendee (uncredited)", "id": 1265826, "name": "Jennifer Lynne Johnson"},
#     {"character": "Prisoner (uncredited)", "id": 193946, "name": "Mark Kubr"},
#     {"character": "Senate Page (uncredited)", "id": 1265827, "name": "Cameron Lee"},
#     {"character": "Reporter (archive footage) (uncredited)", "id": 201951, "name": "Jee-Yun Lee"},
#     {"character": "Expo Guest (uncredited)", "id": 1200895, "name": "Waymond Lee"},
#     {"character": "Prison Guard Chevalier (uncredited)", "id": 1200313, "name": "Mathew Lorenceau"},
#     {"character": "Reporter (uncredited)", "id": 101037, "name": "Christopher Maleki"},
#     {"character": "Photographer at Senate hearing (uncredited)", "id": 1265828, "name": "Richard Markman"},
#     {"character": "Expo Guest (uncredited)", "id": 1265829, "name": "Bryan McCoy"},
#     {"character": "Awards Attendee (uncredited)", "id": 1186481, "name": "Ed Moy"},
#     {"character": "Russian Woman (uncredited)", "id": 1265830, "name": "Delka Nenkova"},
#     {"character": "SWAT Sergeant Bellows (uncredited)", "id": 992389, "name": "Tony Nevada"},
#     {"character": "Watermelon Girl (uncredited)", "id": 1265831, "name": "Allison Ochmanek"},
#     {"character": "French Reporter (uncredited)", "id": 208056, "name": "Nicolas Pajon"},
#     {"character": "White House Chief of Staff (uncredited)", "id": 1265832, "name": "H.E. Victor J.W. Pekarcik III"},
#     {"character": "Expo Guest (uncredited)", "id": 1265833, "name": "Erin Pickett"},
#     {"character": "Expo VIP (uncredited)", "id": 223048, "name": "Olivia Presley"},
#     {"character": "Senate Gallery Member (uncredited)", "id": 1197358, "name": "Steven James Price"},
#     {"character": "Expo Kid (uncredited)", "id": 1265834, "name": "Kiana Prudhont"},
#     {"character": "VIP Expo Guest (uncredited)", "id": 1265835, "name": "Kristin Quick"},
#     {"character": "1960's Film Crew (uncredited)", "id": 1265836, "name": "Tanner Alexander Redman"},
#     {"character": "Security Guard Fighting Happy Hogan (uncredited)", "id": 77824, "name": "Tanoai Reed"},
#     {"character": "Stark Expo Attendee (uncredited)", "id": 1197040, "name": "Kelly Sarah"},
#     {"character": "Pepper's Birthday Party Guest (uncredited)", "id": 1265837, "name": "Torin Sixx"},
#     {"character": "Senator (uncredited)", "id": 1265838, "name": "Peter Trenholm Smith"},
#     {"character": "Model (uncredited)", "id": 1265839, "name": "Grace Stanley"},
#     {"character": "Party Guest (uncredited)", "id": 92189, "name": "Doug Swander"},
#     {"character": "US Senator (uncredited)", "id": 1265840, "name": "Michael A. Templeton"},
#     {"character": "Background (uncredited)", "id": 1265841, "name": "Rosa Tyabji"},
#     {"character": "Tony Stark Usher (uncredited)", "id": 1122811, "name": "Peter Sebastian Wrobel"},
#     {"character": "Expo Attendee (uncredited)", "id": 1205141, "name": "Maria Zambrana"},
#     {"character": "Stark Expo Attendee (uncredited)", "id": 1429470, "name": "Nick W. Nicholson"}
# ]

# # Create DataFrame
# df = pd.DataFrame(data)

# # Print DataFrame
# print(df)
# Out:
#                                             character       id  \
# 0                               Ivan Vanko / Whiplash     2295
# 1    Natalie Rushman / Natasha Romanoff / Black Widow     1245
# 2                                       Justin Hammer     6807
# 3                                  Director Nick Fury     2231
# 4                             Virginia 'Pepper' Potts    12052
# ..                                                ...      ...
# 110                           US Senator (uncredited)  1265840
# 111                           Background (uncredited)  1265841
# 112                     Tony Stark Usher (uncredited)  1122811
# 113                        Expo Attendee (uncredited)  1205141
# 114                  Stark Expo Attendee (uncredited)  1429470
#
#                        name
# 0             Mickey Rourke
# 1        Scarlett Johansson
# 2              Sam Rockwell
# 3         Samuel L. Jackson
# 4           Gwyneth Paltrow
# ..                      ...
# ...

# %%
# df.to_csv('iron_2_actors.csv', index=False)
